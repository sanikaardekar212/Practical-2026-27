# %%
str1='dkte'
str2='college'
print(str1+str2)
# Out:
# dktecollege

# %%
str1='dkte \n'
str2='college'
print(str1+str2)
# Out:
# dkte
# college

# %%
str1='dkte \t'
str2='college'
print(str1+str2)
# Out:
# dkte 	college

# %%
str1='dkte'
str2='college'
print(str1+'  '+str2)
# Out:
# dkte  college

# %%
str1 ='dkte'
str2 ='college'
print(len(str1))
print(len(str2))
# Out:
# 4
# 7

# %%
str1 ='dkte'
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])

print(str1[1+2])
# Out:
# d
# k
# t
# e
# e

# %%
str1='dkte'
str2='college'
print(str1[0:3])
print(str1[1:3])
print(str2[1:5])
print(str2[:5])
print(str2[1:])
print(str2[:])
# Out:
# dkt
# kt
# olle
# colle
# ollege
# college

# %%
str='dkte'
print(str[-3:-1])
print(str[-4:-2])
# Out:
# kt
# dk

# %%
str1 ='dkte'
str2 ='college'
print(str1.startswith('a'))
print(str2.startswith('c'))
# Out:
# False
# True

# %%
str1 ='dkte'
str2 ='college'
str3 ="I am a coder."
print(str1.endswith('e'))
print(str2.endswith('o'))
print(str3.endswith('er.'))
print(str3.endswith('er'))
# Out:
# True
# False
# True
# False

# %%
str1 ='DkTe'
str2='COLlEGe'
str3 = 'ICHAlkarnJI'
str4='FUnctiONS'
str5='dkte'
str6='DKTE'
print(str1.upper())
print(str2.upper())
print(str3.lower())
print(str4.lower())
print(str5.upper())
print(str6.lower())
# Out:
# DKTE
# COLLEGE
# ichalkarnji
# functions
# DKTE
# dkte

# %%
str ='college'
str1 ='dkte'
print(str.title())
print(str1.title())
# Out:
# College
# Dkte

# %%
str1 ='Alphabets'
str2 ='DKTE'
str3='dkte'
str4='123'
str5='15'

print(str1.isalpha())
print(str2.isupper())
print(str3.islower())
print(str4.isnumeric())
print(str5.isdecimal())
# Out:
# True
# True
# True
# True
# True

# %%
str1='ichalkaranji'
print(str1.find('c'))
print(str1.find('i'))
print(str1.count('a'))
print(str1.replace('a','b'))
# Out:
# 1
# 0
# 3
# ichblkbrbnji

# %%
 print("welcome")
# Out:
# welcome

# %%
a = int(input("Enter the num1"))
b = int(input("Enter the num2"))
print("Addition : ",a+b)
# Out:
# Enter the num112
# Enter the num222
# Addition :  34

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 45
# Odd

# %%
a = int(input("Enter the number a:"))
b = int(input("Enter the number b:"))
if a>b:
  print("largest :",a)
else:
  print("largest :",b)
# Out:
# Enter the number a:223
# Enter the number b:2323
# largest : 2323

# %%
a = int(input("Enter the number"))
if a>0:
  print("positive")
elif a<0 :
  print("negative")
else:
  print("zero")
# Out:
# Enter the number22
# positive

# %%
age = 25
if age>=18 :
    print("Elligible for voting")
# Out:
# Elligible for voting

# %%
age =int(input("Enter the age"))
if age>=18 :
    print("Elligible")
else :
    print("Not elligible")
# Out:
# Enter the age18
# Elligible

# %%
marks =int(input("Enter the marks :"))
if marks>=90 :
    print("Grade A")
elif marks>=80 :
    print("Grade B")
elif marks>=70 :
    print("Grade C")
else :
    print("Grade D")
# Out:
# Enter the marks :45
# Grade D

# %%
a =int(input("Enter a number :"))
if a%2==0 :
    print("Even")
else :
    print("Odd")
# Out:
# Enter a number :55
# Odd

# %%
year =int(input("Enter the year :"))
if (year%4==0) and (year%400==0 or year%100!=0) :
    print("year is leap")
else :
    print("year is not leap")
# Out:
# Enter the year :72002
# year is not leap

# %%
age = 25
citizen = True
if age>18 :
   if citizen :
      print("Can drive")
   else :
      print("Cannot drive")
else :
      print("Not Elligible")
# Out:
# Can drive

# %%
age = 18
if age>=18 and age<=90 :
  print("Can drive")
if age>=18 or age<=90 :
  print("Can drive")
if not age<18 :
    print("cannot drive")
# Out:
# Can drive
# Can drive
# cannot drive

# %%
salary =int(input("Enter the salary :"))
experience =int(input("Enter the years :"))
if salary>60000 and experience > 4:
  print("Elligible for promotion")
elif salary>=80000 or experience <2:
  print("Elligible for promotion")
elif salary >50000 or experience >3:
  print("Elligible for promotion")
else :
  print("Not elligible")
# Out:
# Enter the salary :65647
# Enter the years :8
# Elligible for promotion

# %%
a = int(input("Enter the number a:"))
b = int(input("Enter the number b:"))
c = int(input("Enter the number c:"))
if a>b and a>c :
  print("a is largest")
elif b>c :
  print("b is largest")
else:
  print("c is largest")
# Out:
# Enter the number a:44
# Enter the number b:5
# Enter the number c:336
# c is largest

# %%
a = int(input("Enter the number a:"))
b = int(input("Enter the number b:"))
c = int(input("Enter the number c:"))
if a>b and a>c :
  print("largest =",a)
elif b>c :
  print("largest=",b)
else:
  print("largest",c)
# Out:
# Enter the number a:45
# Enter the number b:44
# Enter the number c:55
# largest 55
